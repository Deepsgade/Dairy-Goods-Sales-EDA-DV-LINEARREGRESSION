# %% [markdown]
# Dairy Goods Sales
#
# The Dairy Goods Sales Dataset provides a detailed and comprehensive collection of data related to dairy farms, dairy products, sales, and inventory management.

# %% [markdown]
# #Import library

# %%
 #data processing, CSV file
import pandas as pd

# %%
# Dataset Loading(csv)
df=pd.read_csv('dairy_dataset.csv')

# %% [markdown]
# #check head,info,describe,shape

# %%
df.head()
# Out:
#         Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
# 3      Telangana                   908.00              89     Small
# 4    Maharashtra                   861.95              21    Medium
#
#          Date  Product ID Product Name                 Brand  \
# 0   2/17/2022           5    Ice Cream           Dodla Dairy
# 1   12/1/2021           1         Milk                  Amul
# 2   2/28/2022           4       Yogurt           Dodla Dairy
# 3    6/9/2019           3       Cheese  Britannia Industries
# 4  12/14/2020           8   Buttermilk          Mother Dairy
#
#    Quantity (liters/kg)  Price per Unit  Total Value  Shelf Life (days)  \
# 0                222.40           85.72   19064.1280                 25
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4325 entries, 0 to 4324
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Location                             4325 non-null   object
#  1   Total Land Area (acres)              4325 non-null   float64
#  2   Number of Cows                       4325 non-null   int64
#  3   Farm Size                            4325 non-null   object
#  4   Date                                 4325 non-null   object
#  5   Product ID                           4325 non-null   int64
#  6   Product Name                         4325 non-null   object
#  7   Brand                                4325 non-null   object
#  8   Quantity (liters/kg)                 4325 non-null   float64
#  9   Price per Unit                       4325 non-null   float64
#  10  Total Value                          4325 non-null   float64
# ...

# %%
#description of the data in the DataFrame.
df.describe()
# Out:
#        Total Land Area (acres)  Number of Cows   Product ID  \
# count              4325.000000     4325.000000  4325.000000
# mean                503.483073       54.963699     5.509595
# std                 285.935061       26.111487     2.842979
# min                  10.170000       10.000000     1.000000
# 25%                 252.950000       32.000000     3.000000
# 50%                 509.170000       55.000000     6.000000
# 75%                 751.250000       77.000000     8.000000
# max                 999.530000      100.000000    10.000000
#
#        Quantity (liters/kg)  Price per Unit   Total Value  Shelf Life (days)  \
# count           4325.000000     4325.000000   4325.000000        4325.000000
# mean             500.652657       54.785938  27357.845411          29.127630
# std              288.975915       26.002815  21621.051594          30.272114
# min                1.170000       10.030000     42.516500           1.000000
# ...

# %%
df.describe(include='object')
# Out:
#        Location Farm Size       Date Product Name Brand Customer Location  \
# count      4325      4325       4325         4325  4325              4325
# unique       15         3       1278           10    11                15
# top       Delhi     Large  1/28/2021         Curd  Amul             Delhi
# freq        525      1462         11          479  1053               499
#
#        Sales Channel
# count           4325
# unique             3
# top           Retail
# freq            1478

# %%
df.shape
# Out:
# (4325, 20)

# %% [markdown]
# #Exploratory Data Analysis

# %% [markdown]
# Data cleaning

# %%
#check missing values
df.isnull().sum()
# Out:
# Location                               0
# Total Land Area (acres)                0
# Number of Cows                         0
# Farm Size                              0
# Date                                   0
# Product ID                             0
# Product Name                           0
# Brand                                  0
# Quantity (liters/kg)                   0
# Price per Unit                         0
# Total Value                            0
# Shelf Life (days)                      0
# Quantity Sold (liters/kg)              0
# Price per Unit (sold)                  0
# Approx. Total Revenue(INR)             0
# Customer Location                      0
# Sales Channel                          0
# Quantity in Stock (liters/kg)          0
# Minimum Stock Threshold (liters/kg)    0
# Reorder Quantity (liters/kg)           0
# dtype: int64

# %%
# To check for duplicate rows  /  ##True=duplicate 1, othwerwise False 0
df.duplicated().sum()
# Out:
# 0

# %%
#converted to datetime.
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
# 3      Telangana                   908.00              89     Small
# 4    Maharashtra                   861.95              21    Medium
#
#         Date  Product ID Product Name                 Brand  \
# 0 2022-02-17           5    Ice Cream           Dodla Dairy
# 1 2021-12-01           1         Milk                  Amul
# 2 2022-02-28           4       Yogurt           Dodla Dairy
# 3 2019-06-09           3       Cheese  Britannia Industries
# 4 2020-12-14           8   Buttermilk          Mother Dairy
#
#    Quantity (liters/kg)  Price per Unit  Total Value  Shelf Life (days)  \
# 0                222.40           85.72   19064.1280                 25
# ...

# %% [markdown]
# #check for outlier

# %%
import seaborn as sns

# %%
sns.boxplot(data=df['Total Value'])
# Out:
# <Axes: >

# %%
# Choose the maximum quartile
TV=df['Total Value'].quantile(0.75)
TV
# Out:
# 40954.441

# %%
df[df['Total Value']>TV]
# Out:
#            Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 5         Telangana                    87.64              51    Medium
# 11       Chandigarh                   648.52              99     Small
# 13        Telangana                   856.00              39     Large
# 14          Gujarat                   182.28              70    Medium
# 19       Tamil Nadu                   534.50              52    Medium
# ...             ...                      ...             ...       ...
# 4316      Telangana                   449.88              28     Small
# 4319  Uttar Pradesh                   269.63              91     Small
# 4320          Delhi                   748.71              89    Medium
# 4321      Jharkhand                   385.91              29     Large
# 4322     Chandigarh                   311.54              65     Small
#
#            Date  Product ID Product Name            Brand  \
# ...

# %%
# remove outliners
df = df[ df['Total Value']<TV ]

# %%
sns.boxplot(x=df['Total Value'])
# Out:
# <Axes: xlabel='Total Value'>

# %%
df.shape
# Out:
# (3243, 20)

# %%
df.columns
# Out:
# Index(['Location', 'Total Land Area (acres)', 'Number of Cows', 'Farm Size',
#        'Date', 'Product ID', 'Product Name', 'Brand', 'Quantity (liters/kg)',
#        'Price per Unit', 'Total Value', 'Shelf Life (days)',
#        'Quantity Sold (liters/kg)', 'Price per Unit (sold)',
#        'Approx. Total Revenue(INR)', 'Customer Location', 'Sales Channel',
#        'Quantity in Stock (liters/kg)', 'Minimum Stock Threshold (liters/kg)',
#        'Reorder Quantity (liters/kg)'],
#       dtype='object')

# %% [markdown]
# #Data Visualization
#
#
#
#
# 1.  UNIVARITE ANALYSIS
#
#
# 2.  BIVARIATE ANALYSIS
#
# 1.   MULTIVATE ANALYSIS

# %% [markdown]
# ##Univariate Analysis : we visualize only a single variable at a time.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# HISTROGRAM: frequency distributions.

# %%
plt.figure(figsize=(10,5))
plt.hist(df['Total Value'], color='gold', edgecolor='darkviolet',bins=50)
plt.xlabel('Total Value')
plt.title('Distribution of Total Value',color='r')
plt.show()

# %%
#USING SEABORN
sns.histplot(df['Approx. Total Revenue(INR)'], color='r', kde=True)
plt.title('Approx. Total Revenue(INR)')
# Out:
# Text(0.5, 1.0, 'Approx. Total Revenue(INR)')

# %% [markdown]
# box plot :visulazing the distribution of NUMERIC values .Boxplot is also used for detect the outlier in data set

# %%
box_plot = sns.boxplot(x='Total Value', data=df, color='red')
plt.title('Box Plot of Total Value',color='green',fontsize='10')
plt.show()

# %% [markdown]
# BAR GRAP :Univariate analysis of categorical data. We’ll be using the count plot function

# %%
sns.countplot(x='Product Name', data=df,palette='bright',edgecolor='black')
plt.xticks(rotation=90)
plt.title('Count Plot of Product Name',color='#A52A2A')
plt.show()

# %% [markdown]
#  HIGH PRODUCT SALE :PANEER

# %%
sns.countplot(data=df, x='Brand',edgecolor='black',palette='muted')
plt.title('Count Plot of Brand',color='#FF4500')
plt.xticks(rotation=80)
plt.show()

# %%
loc = df['Location'].value_counts()[:]
loc.plot(kind='bar',figsize=(10,4),color='#3CB371')
plt.title('Location State wise',color='#8B4789')
# Out:
# Text(0.5, 1.0, 'Location State wise')

# %% [markdown]
# #Bivariate analysis :Bivariate analysis is the simultaneous analysis of two variable

# %%
df.columns
# Out:
# Index(['Location', 'Total Land Area (acres)', 'Number of Cows', 'Farm Size',
#        'Date', 'Product ID', 'Product Name', 'Brand', 'Quantity (liters/kg)',
#        'Price per Unit', 'Total Value', 'Shelf Life (days)',
#        'Quantity Sold (liters/kg)', 'Price per Unit (sold)',
#        'Approx. Total Revenue(INR)', 'Customer Location', 'Sales Channel',
#        'Quantity in Stock (liters/kg)', 'Minimum Stock Threshold (liters/kg)',
#        'Reorder Quantity (liters/kg)'],
#       dtype='object')

# %% [markdown]
# HISTROGRAM -USING 2 VARIABLE

# %%
plt.figure()
plt.hist(df['Customer Location'], color='skyblue', edgecolor='red',bins=15)
plt.xlabel('Customer Location')
plt.ylabel('Approx. Total Revenue(INR)')
plt.title('Distribution of total revenue by Customer Location',color='m')
plt.xticks(rotation=80)
#plt.grid(axis='y',alpha=0.75)
plt.show()

# %% [markdown]
# HIGH SALES OF CUSTOMER LOCATION: DELHI

# %% [markdown]
# BOXPLOT: USING 2 VARIABLE

# %%
sns.boxplot(data=df, x='Product Name', y='Total Value')
plt.title('Box Plot of Total Value by Product Name')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,4))
sns.catplot(data=df, x='Product ID', y='Price per Unit (sold)',hue='Farm Size',
    kind='box',palette='PiYG')

# %%
box_plot = sns.boxplot(x='Brand', y='Quantity Sold (liters/kg)', data=df,palette='pastel')
plt.xticks(rotation=90,color='r')
plt.title('Distribution Quantity Sold')
plt.show()

# %% [markdown]
# scatter plot :A scatter plot is a diagram where each value in the data set is represented by a dot.
#
# 'hue' is used to visualize the data of different categories in one plot. 'palette' is used to change the colour of the plot.

# %%
fig, axis = plt.subplots(figsize=(7,5))
sns.scatterplot(x='Product Name', y='Total Value',hue='Sales Channel', data=df, ax=axis,palette='pastel',s=50)
plt.title('Distribution of total values by product name ')
plt.xticks(rotation=90)
plt.show()

# %%
# Scatter Plot using PANDAS
df.plot.scatter(x='Total Value', y='Approx. Total Revenue(INR)', c='orange', s=10, figsize=(10,7))
plt.title('Total Value vs Approx. Total Revenue(INR)')
plt.show()

# %%
df.plot.scatter(x='Sales Channel', y='Approx. Total Revenue(INR)', c='c', s=10, figsize=(10,7))
plt.title('Approx. Total Revenue(INR) vs Sales Channel')
plt.show()

# %% [markdown]
# HIGH SALING IS RETAILER

# %% [markdown]
# BARPLOT

# %%
sns.barplot(data=df, x='Brand', y='Total Value',palette='colorblind')
plt.title('Bar Plot of Total Value by Brand')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# LINEPLOT

# %%
plt.figure(figsize=(12,5))
sns.lineplot(data=df, x='Date', y='Total Value',hue='Farm Size',palette='muted')
plt.title('Line Plot of Total Value over Time')
plt.xticks(rotation=45)
plt.show()

# %%
# Scatter Plot using seaborn
sns.scatterplot(data=df, x='Quantity (liters/kg)', y='Approx. Total Revenue(INR)',color='g',edgecolor='r')
plt.title('Scatter Plot of Quantity vs. Approx. Total Revenue',fontsize = 10, fontweight='bold',color='orange')
plt.show()

# %% [markdown]
# #Multivariate Analysis:  more than two variables in the data set.

# %% [markdown]
# pairplot :To plot multiple pairwise bivariate distributions in a dataset, you can use the . pairplot() function.

# %%
#sns.pairplot(df)
#plt.show()

# %%
plt.figure(figsize=(15,7))
sns.pairplot(data=df, vars=['Total Value', 'Quantity (liters/kg)', 'Approx. Total Revenue(INR)'])
plt.title('pairplot',fontsize='20',color='brown')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.pairplot(data=df, vars=['Total Value', 'Quantity Sold (liters/kg)', 'Approx. Total Revenue(INR)'],hue='Product Name',palette='bright')
plt.show()

# %% [markdown]
# heatmap : A heatmap is a two-dimensional graphical representation of data where the individual values that are contained in a matrix are represented as colours.

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, edgecolor='black')
plt.title('Correlation Matrix')
# Out:
# <ipython-input-177-41e921be49b3>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, edgecolor='black')
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
df.columns
# Out:
# Index(['Location', 'Total Land Area (acres)', 'Number of Cows', 'Farm Size',
#        'Date', 'Product ID', 'Product Name', 'Brand', 'Quantity (liters/kg)',
#        'Price per Unit', 'Total Value', 'Shelf Life (days)',
#        'Quantity Sold (liters/kg)', 'Price per Unit (sold)',
#        'Approx. Total Revenue(INR)', 'Customer Location', 'Sales Channel',
#        'Quantity in Stock (liters/kg)', 'Minimum Stock Threshold (liters/kg)',
#        'Reorder Quantity (liters/kg)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3243 entries, 0 to 4324
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Location                             3243 non-null   object
#  1   Total Land Area (acres)              3243 non-null   float64
#  2   Number of Cows                       3243 non-null   int64
#  3   Farm Size                            3243 non-null   object
#  4   Date                                 3243 non-null   datetime64[ns]
#  5   Product ID                           3243 non-null   int64
#  6   Product Name                         3243 non-null   object
#  7   Brand                                3243 non-null   object
#  8   Quantity (liters/kg)                 3243 non-null   float64
#  9   Price per Unit                       3243 non-null   float64
#  10  Total Value                          3243 non-null   float64
# ...

# %%
x = df['Quantity Sold (liters/kg)'].to_frame()  #independent variable
y = df['Approx. Total Revenue(INR)']            # dependent variable

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y ,color='y')
plt.xlabel('Quantity Sold (liters/kg)')
plt.ylabel('Approx. Total Revenue(INR)')
plt.show()

# %% [markdown]
# SPLIT THE DATA:TRAIN & TEST 75:25

# %%
from sklearn.model_selection import train_test_split
# split the dataset into 75% for training and 25% for testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=78)

# %%
x_train.shape
# Out:
# (2432, 1)

# %%
x_test.shape
# Out:
# (811, 1)

# %% [markdown]
# #LinearRegression

# %% [markdown]
# Import sklearn
#
# fit method

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
m = reg.coef_[0]
c = reg.intercept_
print(f"Slope / Regression co-efficient m = {m} \n\t y-intercept c = {c}")
# Out:
# Slope / Regression co-efficient m = 32.29187751405875
# 	 y-intercept c = 1897.0572290227774

# %%
X = x.to_numpy()
y_pred = m*X + c

# %%
plt.scatter(x,y, color='tomato')
plt.plot(X, y_pred, c='g')
plt.xlabel('Quantity Sold (liters/kg)')
plt.ylabel('Approx. Total Revenue(INR)')
plt.title('LinearRegression with slope')
plt.show()

# %%
y_pred = reg.predict(x_test)

# %%
from sklearn.metrics import r2_score

r_squared_score = r2_score(y_test, y_pred)
print("R-squared score = ", r_squared_score)
# Out:
# R-squared score =  0.5564076828131902

# %% [markdown]
# Accuracy score is :0.5564076828131902
